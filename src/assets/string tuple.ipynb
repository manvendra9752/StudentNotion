# %%
#command line input
username=input("enter username")
print("username is:"+username)
# Out:
# enter usernamepython
# username is:python

# %%
num=input("enter number:")
print(num)
name=input("enter name:")
print(name)
print("type of datatype",type(num))
# Out:
# enter number:12
# 12
# enter name:rati
# rati
# type of datatype <class 'str'>

# %%
print("enter your name:")
x=input()
print("hello",x)
# Out:
# enter your name:
# john
# hello john

# %%
# type conversion
x=1.9 #float
y=5  #int
z= 2j   # complex
a=int(x)
b=float(y)
c=complex(y)
print(a,b,c)
# Out:
# 1 5.0 (5+0j)

# %%
#strings(multiline strings)
x="""hiiii we live in
Indore"""
print(x)
y='''hiii
we live in Indore'''
print(y)
# Out:
# hiiii we live in
# Indore
# hiii
# we live in Indore

# %%
#(extracting individual character)
my_string="Indore Institute of science and technology"
my_string[5]
# Out:
# 'e'

# %%
my_string="Indore Institute of Science and Technology"
my_string[-1]
# Out:
# 'y'

# %%
my_string="Indore Institute of Science and Technology"
my_string[5:11]
# Out:
# 'e Inst'

# %%
#string functions
#finding length of string
my_string="indore institute of science and technology"
print(len(my_string))
# Out:
# 42

# %%
a=input("enter string")
print(len(a))
# Out:
# enter stringhow are you
# 11

# %%
my_string="Indore Institute of Science and Technology"
my_string[:5]
# Out:
# 'Indor'

# %%
my_string="Indore Institute of Science and Technology"
my_string[3:]
# Out:
# 'ore Institute of Science and Technology'

# %%
a="Invigilator"
a[-5:-2]
# Out:
# 'lat'

# %%
#converting string to lower case
a="MY NAME IS JOHN"
a.lower()
# Out:
# 'my name is john'

# %%
#converting string to upper case
a="my name is john"
a.upper()
# Out:
# 'MY NAME IS JOHN'

# %%
a='''ashbsnm'''
print(a.capitalize())
# Out:
# Ashbsnm

# %%
a='''the capital of madhya pradesh is bhopal'''
a.islower()
# Out:
# True

# %%
a='''the capital of madhya pradesh is bhopal'''
a.isupper()
# Out:
# False

# %%
a='''THe Capital of mAdhyA pradesh is bhopal'''
a.swapcase()
# Out:
# 'thE cAPITAL OF MaDHYa PRADESH IS BHOPAL'

# %%
a='''THe Capital of mAdhyA pradesh is bhopal'''
a.title()
# Out:
# 'The Capital Of Madhya Pradesh Is Bhopal'

# %%
a='''THe Capital of madhya pradesh is bhopal'''
a.partition(' ')
# Out:
# ('THe', ' ', 'Capital of madhya pradesh is bhopal')

# %%
#replacing a substring
a="my name is john"
print(a)
print(a.replace('my name is','myself'))
# Out:
# my name is john
# myself john

# %%
#number of occurence of substring
my_string="my name is john,my pet name is jojo"
my_string.count('my')
# Out:
# 2

# %%
#finding the index of substring
s1="this is shocking news"
print(s1.find('shocking'))
print(s1.index("i",10,14))
print(s1.find("q"))
# Out:
# 8
# 13
# -1

# %%
#splitting a string
fruit="I like apples,mangoes,oranges"
fruit.split(',')
# Out:
# ['I like apples', 'mangoes', 'oranges']

# %%
fruit="I like apples,mangoes,oranges"
fruit.split('e')
# Out:
# ['I lik', ' appl', 's,mango', 's,orang', 's']

# %%
#strip
a="   hello,IIST "
print(a)
print(a.strip())
# Out:
#    hello,IIST
# hello,IIST

# %%
strng=",,,,,,,,rrthfd....Geniusrrr...rr,r"
x=strng.strip(",r")
print(x)
# Out:
# thfd....Geniusrrr...

# %%
age=20
str="my name is john and my age is:"+ age
print(str)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-a588bfabeb31> in <cell line: 2>()
#       1 age=20
# ----> 2 str="my name is john and my age is:"+ age
#       3 print(str)
#
# TypeError: can only concatenate str (not "int") to str

# %%
#format() method
age=20
txt="my name is john and my age is{}"
print(txt.format(age))
# Out:
# my name is john and my age is20

# %%
a=3
b=1
c=4
txt="IIST{} IIP{} IIMR{}"
print(txt.format(a,b,c))
# Out:
# IIST3 IIP1 IIMR4

# %%
a=3
b=1
c=4
txt="IIST{1} IIP{0} IIMR{2}"
print(txt.format(a,b,c))
# Out:
# IIST1 IIP3 IIMR4

# %%
#check string (check if flower is present in string)
txt='This is flower'
print("flower" in txt)
# Out:
# True

# %%
txt="This is flower"
print("flower" not in txt)
# Out:
# False

# %%
a='''bhuyjbcjkhdisasjk\nkjdsajkjsadjksajksa
hgghjbjkhh'''
print(a.splitlines())
# Out:
# ['bhuyjbcjkhdisasjk', 'kjdsajkjsadjksajksa', 'hgghjbjkhh']

# %%
txt="This is flower"
txt.startswith('is')
# Out:
# False

# %%
print("It\'s a \"wonderful\" day")
# Out:
# It's a "wonderful" day

# %%
#Tuple
tup1=(1,'two',True,1)
print(tup1)
# Out:
# (1, 'two', True, 1)

# %%
tup1=(1,"one",False,3.6)
type(tup1)
# Out:
# tuple

# %%
#create tuple with one item
tup1=("apple",)
print(tup1)
print(type(tup1))
# Out:
# ('apple',)
# <class 'tuple'>

# %%
#not a tuple
tup1=("apple")
print(type(tup1))
# Out:
# <class 'str'>

# %%
#extracting individual elements:
tup1=(1,"a",False,2,3.5,3j)
tup1[5]
# Out:
# 3j

# %%
tup1=(1,"a",True,2,3.5,3j,1)
tup1[-3]
# Out:
# 3.5

# %%
tup1=(1,"a",False,2,3.5,3j)
tup1[1:4]
# Out:
# ('a', False, 2)

# %%
tup1=(1,"a",True,2,3.5,3j)
tup1[:4]
# Out:
# (1, 'a', True, 2)

# %%
tup1=(1,"a",False,2,3.5,3j)
tup1[2:]
# Out:
# (False, 2, 3.5, 3j)

# %%
#tuple index method
tup1=(1,"a",False,2,3.5,3j)
print(tup1.index(1))
print(tup1.index("a"))
print(tup1.index(False))
print(tup1.index(2))
print(tup1.index(3.5))
print(tup1.index(3j))
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
#finding length of tuple
tup1=(1,3.5,"good",True)
len(tup1)
# Out:
# 4

# %%
#change values
a=(1,2,"three",True)
b=list(a)
b[3]=False
a=tuple(b)
print(a)
# Out:
# (1, 2, 'three', False)

# %%
a=(56,90,"hi",False)
b=list(a)
b.append(543)
a=tuple(b)
print(a)
# Out:
# (56, 90, 'hi', False, 543)

# %%
a=(56,90,"hi",False)
b=list(a)
b.remove(90)
a=tuple(b)
print(a)
# Out:
# (56, 'hi', False)

# %%
#concatenating tuple
tup1=(1,2,3.5,"good")
tup2=(True,False)
print(tup1+tup2)
# Out:
# (1, 2, 3.5, 'good', True, False)

# %%
#repeating tuple element
tup1=("happy",400,True)
print(tup1*15)
# Out:
# ('happy', 400, 'happy', 400, 'happy', 400, 'happy', 400, 'happy', 400, 'happy', 400, 'happy', 400, 'happy', 400, 'happy', 400, 'happy', 400, 'happy', 400, 'happy', 400, 'happy', 400, 'happy', 400, 'happy', 400)

# %%
#repeating and concatenating
tup1=("happy",400 )
tup2=(True,False)
tup1*2+tup2
# Out:
# ('happy', 400, 'happy', 400, True, False)

# %%
tup1=("happy","Happy" )
max(tup1)
# Out:
# 'happy'

# %%
tup1=(5,800,120)
min(tup1)
# Out:
# 5

# %%
tup1=(True,False)
max(tup1)
# Out:
# True

# %%
user=input("enter values")
tup=tuple(int(item) for item in user.split())
print(tup)
# Out:
# enter values8 9 7 6
# (8, 9, 7, 6)

# %%
tup=tuple(input('enter values using comma:').split(','))
print(tup)
# Out:
# enter values using comma:2,6,4,7,8,rf,rt,s
# ('2', '6', '4', '7', '8', 'rf', 'rt', 's')
