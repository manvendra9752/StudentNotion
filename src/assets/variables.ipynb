# %%
print("hello")
# Out:
# hello

# %%
#This is comment
print("this is comment")
# Out:
# this is comment

# %%
x=5
y="john"
print(x)
print(y)
# Out:
# 5
# john

# %%
x=5
print(x)
# Out:
# 5

# %%
# casting(if you want to specify the data typeof a variabe)
x=str('abc')
y=int(3)
z=float(3)
print(x)
print(y)
print(z)
# Out:
# abc
# 3
# 3.0

# %%
x=str(3)
y=str(4)
z=x+y
print(z)
# Out:
# 34

# %%
x=5
y="john"
print(type(x))
# Out:
# <class 'int'>

# %%
x="hey..."

x='hey'

x='''hey..'''
print(x)
# Out:
# hey..

# %%
x="hey"
print(x)
x='hey'
print(x)
# Out:
# hey
# hey

# %%
myvar="hello"
print(myvar)
MYVAR="HII"
print(MYVAR)
# Out:
# hello
# HII

# %%
myVar="hello"
print(myVar)
2myvar="hello"
print(2myvar)
# Out:
#   File "<ipython-input-16-e51f0a1ab8d9>", line 3
#     2myvar="hello"
#          ^
# SyntaxError: invalid syntax

# %%
x,y,z="one","two","three"
print(x)print(y)print(z)
# Out:
#   File "<ipython-input-18-df00ad2598ab>", line 2
#     print(x)print(y)print(z)
#                 ^
# SyntaxError: invalid syntax

# %%
x=y=z="one"
print(x)
print(y)
print(z)
# Out:
# one
# one
# one

# %%
x="python"
y="is"
z="good"
a="language"
print(x,y,z,a)
# Out:
# python is good language

# %%
# many values to multiple variables
x,y,z="one","two","three"
print(x,y,z)
# Out:
# one two three

# %%
x="python"
y="is"
print(x+y)
# Out:
# pythonis

# %%
x=5
y=6
print(x+y)
# Out:
# 11

# %%
x=3
print(type(x))
# Out:
# <class 'int'>

# %%
#taking input from the user
user=input("enter username")
print("username is:" +user)
print(type(user))
# Out:
# enter usernamehimani
# username is:himani
# <class 'str'>

# %%
num=input("enter number:")
print(num)
name1=input("enter name:")
print('hello,'+ name1)
print(type(num))
# Out:
# enter number:23
# enter name:parul
# "<class 'str'>"

# %%
value=input("please enter value:")
print(value)
print(type(value))
# Out:
# please enter value:12
# "<class 'str'>"

# %%
value=input("please enter value:")
print(value)
print(type(value))
value=value+1
print(value)
# Out:
# please enter value:23
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-704ecd242619> in <cell line: 4>()
#       2 print(value)
#       3 print(type(value))
# ----> 4 value=value+1
#       5 print(value)
#
# TypeError: can only concatenate str (not "int") to str

# %%
value=int(input("please enter value:"))
print(value)
print(type(value))
value=value+1
print(value)
# Out:
# please enter value:23
# '24'

# %%
value=float(input("please enter value:"))
print(value)
print(type(value))
value=value+1
print(value)
# Out:
# please enter value:23
# 23.0
# <class 'float'>
# 24.0

# %%
#taking input from user
value=int(input("please enter value:"))
print(value)
print(type(value))
# Out:
# please enter value:8
# 8
# <class 'int'>

# %%
a=input("hello")
print(a*10)
# Out:
# hellocs2
# cs2cs2cs2cs2cs2cs2cs2cs2cs2cs2

# %%
print("welcome",end='')
print("user")
# Out:
# welcomeuser

# %%
print("welcome","hello",sep='--')
print("user")
# Out:
# welcome--hello
# user

# %%
#TYPE CASTING
a=5
n=float(a)
print(n)
print(type(n))
# Out:
# "<class 'float'>"

# %%
a=5
n=str(a)
print(n)
print(type(n))
# Out:
# "<class 'str'>"
